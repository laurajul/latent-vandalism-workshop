# %%
# Force all caches to use scratch via the symlink
import os
from pathlib import Path

# Set cache directories to use the symlink
cache_dir = str(Path.home() / "data" / ".cache")

os.environ["HF_HOME"] = cache_dir
os.environ["TORCH_HOME"] = cache_dir
os.environ["TRANSFORMERS_CACHE"] = cache_dir
os.environ["HF_HUB_CACHE"] = cache_dir
os.environ["UV_CACHE_DIR"] = cache_dir

print("✓ Cache directories set to:", cache_dir)
print("✓ This symlinks to /scratch/lauwag/cache")
# Out:
# ✓ Cache directories set to: /home/lauwag/data/.cache
# ✓ This symlinks to /scratch/lauwag/cache
